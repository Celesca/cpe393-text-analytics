# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ## Load data

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df['Maker_Model']= df['Make']+ " " + df['Model']

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP     Maker_Model
# 0               26        19        3916  46135  BMW 1 Series M
# 1               28        19        3916  40650    BMW 1 Series
# 2               28        20        3916  36350    BMW 1 Series
# 3               28        18        3916  29450    BMW 1 Series
# 4               28        18        3916  34500    BMW 1 Series
# ...            ...       ...         ...    ...             ...
# 11909           23        16         204  46120       Acura ZDX
# 11910           23        16         204  56670       Acura ZDX
# 11911           23        16         204  50620       Acura ZDX
# 11912           23        16         204  50920       Acura ZDX
# 11913           26        17          61  28995  Lincoln Zephyr
#
# [11914 rows x 17 columns]

# %%
# Select features from original dataset to form a new dataframe
df1 = df[['Engine Fuel Type','Transmission Type','Driven_Wheels','Market Category','Vehicle Size', 'Vehicle Style', 'Maker_Model']]
df1.head()
# Out:
#               Engine Fuel Type Transmission Type     Driven_Wheels  \
# 0  premium unleaded (required)            MANUAL  rear wheel drive
# 1  premium unleaded (required)            MANUAL  rear wheel drive
# 2  premium unleaded (required)            MANUAL  rear wheel drive
# 3  premium unleaded (required)            MANUAL  rear wheel drive
# 4  premium unleaded (required)            MANUAL  rear wheel drive
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#       Maker_Model
# 0  BMW 1 Series M
# 1    BMW 1 Series
# 2    BMW 1 Series
# 3    BMW 1 Series
# 4    BMW 1 Series

# %%
# For each row, combine all the columns into one column
df2 = df1.apply(lambda x: ','.join(x.astype(str)), axis=1)
df2.head()
# Out:
# 0    premium unleaded (required),MANUAL,rear wheel ...
# 1    premium unleaded (required),MANUAL,rear wheel ...
# 2    premium unleaded (required),MANUAL,rear wheel ...
# 3    premium unleaded (required),MANUAL,rear wheel ...
# 4    premium unleaded (required),MANUAL,rear wheel ...
# dtype: object

# %%
df2.shape
# Out:
# (11914,)

# %%
# Store them in a pandas dataframe
df_clean = pd.DataFrame({'clean': df2})
df_clean.head()
# Out:
#                                                clean
# 0  premium unleaded (required),MANUAL,rear wheel ...
# 1  premium unleaded (required),MANUAL,rear wheel ...
# 2  premium unleaded (required),MANUAL,rear wheel ...
# 3  premium unleaded (required),MANUAL,rear wheel ...
# 4  premium unleaded (required),MANUAL,rear wheel ...

# %%
# Create the list of list format of the custom corpus for gensim modeling
sent = [row.split(',') for row in df_clean['clean']]
# show the example of list of list format of the custom corpus for gensim modeling
sent[:2]
# Out:
# [['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series M'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series']]

# %%
sent
# Out:
# [['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series M'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 1 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 1 Series'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 100'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 100'],
#  ['premium unleaded (recommended)',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'FIAT 124 Spider'],
#  ['premium unleaded (recommended)',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'FIAT 124 Spider'],
#  ['premium unleaded (recommended)',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'FIAT 124 Spider'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Mercedes-Benz 190-Class'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'BMW 2 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'BMW 2 Series'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Audi 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Audi 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Wagon',
#   'Audi 200'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Audi 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Flex Fuel',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['flex-fuel (unleaded/E85)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Flex Fuel',
#   'Midsize',
#   'Sedan',
#   'Chrysler 200'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 200SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 240SX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 240'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 240'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 2'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'BMW 3 Series Gran Turismo'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Hybrid',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['premium unleaded (recommended)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Midsize',
#   'Sedan',
#   'BMW 3 Series'],
#  ['diesel',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'BMW 3 Series'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Coupe',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Coupe',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Coupe',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 300-Class'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Hatchback',
#   'Factory Tuner',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Hatchback',
#   'Factory Tuner',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Hatchback',
#   'Factory Tuner',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mitsubishi 3000GT'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'all wheel drive',
#   'nan',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Large',
#   'Sedan',
#   'Chrysler 300M'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 300ZX'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '2dr Hatchback',
#   'Mazda 323'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 350-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 350-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 350-Class'],
#  ['diesel',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Diesel',
#   'Luxury',
#   'Large',
#   'Sedan',
#   'Mercedes-Benz 350-Class'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 350Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Exotic',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Ferrari 360'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Factory Tuner',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['premium unleaded (required)',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Nissan 370Z'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Performance',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'nan',
#   'Compact',
#   'Sedan',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Compact',
#   '4dr Hatchback',
#   'Mazda 3'],
# ...
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Factory Tuner',
#   'Luxury',
#   'Performance',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Midsize',
#   '4dr Hatchback',
#   'Saab 9000'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '4dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Saab 900'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['regular unleaded',
#   'MANUAL',
#   'front wheel drive',
#   'Luxury',
#   'Compact',
#   'Sedan',
#   'Audi 90'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'rear wheel drive',
#   'Factory Tuner',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'AUTOMATED_MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'all wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 911'],
#  ['premium unleaded (required)',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'High-Performance',
#   'Compact',
#   'Coupe',
#   'Porsche 911'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Porsche 928'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Porsche 928'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Porsche 928'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Midsize',
#   'Sedan',
#   'Mazda 929'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Midsize',
#   'Sedan',
#   'Mazda 929'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'nan',
#   'Midsize',
#   'Sedan',
#   'Mazda 929'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Wagon',
#   'Volvo 940'],
#  ['regular unleaded',
#   'AUTOMATIC',
#   'rear wheel drive',
#   'Luxury',
#   'Midsize',
#   'Sedan',
#   'Volvo 940'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Hatchback',
#   'Luxury',
#   'Performance',
#   'Compact',
#   '2dr Hatchback',
#   'Porsche 944'],
#  ['regular unleaded',
#   'MANUAL',
#   'rear wheel drive',
#   'Luxury',
#   'Performance',
#   'Compact',
#   'Convertible',
#   'Porsche 944'],
#  ...]

# %% [markdown]
# ## Train Word2Vec model (skip-gram)

# %%
# from gensim import models
from gensim.models import Word2Vec
model = Word2Vec(sent, min_count=1,vector_size= 300,workers=5, window=10, sg = 1, epochs=100)
# model = Word2Vec(sent, min_count=1,size= 300,workers=5, window=10, sg = 1, iter=100)

# %% [markdown]
# **vector_size**: The number of dimensions of the embeddings and the default is 100.
#
# **window**: The maximum distance between a target word and words around the target word. The default window is 5.
#
# **min_count**: The minimum count of words to consider when training the model; words with occurrence less than this count will be ignored. The default for min_count is 5.
#
# **workers**: The number of partitions during training and the default workers is 3.
#
# **sg**: The training algorithm, either CBOW(0) or skip gram(1). The default training algorithm is CBOW.

# %%
model.wv['Toyota Camry']
# Out:
# array([ 1.49983510e-01, -8.24586675e-03,  1.63055491e-02, -5.11664860e-02,
#         6.57137632e-02, -5.81669658e-02, -1.39558036e-02,  1.50270596e-01,
#        -1.65718958e-01, -5.09733483e-02,  7.92334154e-02, -9.20385644e-02,
#         1.70094013e-01,  1.17997810e-01, -3.33329588e-02,  3.58268321e-02,
#         3.91791105e-01,  1.14242554e-01, -1.11751795e-01, -1.30083412e-02,
#        -7.91098103e-02, -6.86028600e-02, -1.96330726e-01,  3.21713656e-01,
#        -1.14573158e-01, -1.25655100e-01, -2.34688759e-01,  1.54945731e-01,
#        -3.52928555e-03, -1.58676878e-01,  4.11659420e-01,  1.11461177e-01,
#        -1.29728973e-01, -1.02372050e-01,  7.74190947e-02, -4.04880792e-02,
#         1.46345630e-01, -2.61880308e-01, -4.75360779e-03,  1.19118489e-01,
#        -2.54214078e-01,  3.67149264e-02,  1.54215679e-01,  2.24054962e-01,
#        -8.93192887e-02,  1.15567874e-02,  3.76445577e-02, -1.35067001e-01,
#         1.11167528e-01,  6.25425577e-02,  1.68894067e-01, -1.68743998e-01,
#         4.60442267e-02, -4.33262810e-02,  2.85073631e-02,  5.51332198e-02,
#        -8.16123784e-02, -3.81392352e-02, -2.54533831e-02,  6.79903179e-02,
#         1.25227794e-01,  1.18682802e-01,  2.46434614e-01,  2.50587344e-01,
#        -3.16089481e-01,  2.84114331e-02,  1.56568706e-01, -8.04193411e-03,
#        -1.25393346e-01,  2.52204508e-01,  1.58017203e-01, -2.91280972e-04,
#         2.56267071e-01, -1.94056749e-01,  1.10814326e-01,  1.63331464e-01,
#        -8.07870701e-02,  1.21136829e-01,  1.36725241e-02, -3.10582612e-02,
#         5.99393025e-02, -1.33771986e-01,  1.77648645e-02,  2.70666063e-01,
#         1.15592174e-01,  7.41543947e-03, -1.00587733e-01, -4.07747328e-02,
#         3.08697909e-01,  2.11757794e-01,  3.49056870e-02,  1.11150987e-01,
#         2.02702314e-01,  7.12927282e-02,  5.67891262e-02,  1.79612905e-01,
#         5.45954295e-02, -1.04920678e-01,  5.42561300e-02, -6.92973360e-02,
#         4.33284417e-02, -3.82714309e-02,  3.83403778e-01, -2.87903458e-01,
#         2.87973434e-01,  1.56374767e-01, -2.50718802e-01, -1.25112176e-01,
#         2.57489771e-01,  4.11889702e-01, -3.58872920e-01, -6.46412894e-02,
#         2.68775038e-02, -1.69614106e-01,  5.45079291e-01, -3.31378989e-02,
#        -3.70167106e-01,  8.28737915e-02,  2.59436071e-01,  1.62330225e-01,
#        -3.55436504e-01,  2.22280636e-01, -2.78163165e-01,  3.25903222e-02,
#        -7.43822530e-02, -1.69060081e-01, -1.26996398e-01, -2.22738862e-01,
#         3.46979089e-02,  2.14949355e-01, -2.88419008e-01, -1.26484662e-01,
#        -1.51118442e-01,  5.28947748e-02, -8.89112428e-02,  2.06740052e-01,
#         1.23921715e-01,  1.76385835e-01, -2.46813893e-01,  1.30564675e-01,
#        -1.30367503e-01,  1.21578522e-01, -1.07077137e-02, -5.24576567e-03,
#        -5.76105826e-02,  1.26341298e-01,  2.10372031e-01, -9.36284512e-02,
#         8.92928690e-02, -6.18369058e-02,  7.42087439e-02, -1.21206880e-01],
#       dtype=float32)

# %%
model.wv.similarity('Porsche 718 Cayman', 'Nissan Van')
# Out:
# 0.59768766

# %%
model.wv.similarity('Porsche 718 Cayman', 'Mercedes-Benz SLK-Class')
# Out:
# 0.8467878

# %%
model.wv.most_similar('Mercedes-Benz SLK-Class')[:5]
# Out:
# [('Mercedes-Benz SL-Class', 0.9813322424888611),
#  ('Cadillac XLR-V', 0.9682995676994324),
#  ('Mercedes-Benz SLC-Class', 0.9639554619789124),
#  ('Porsche Boxster', 0.9320353269577026),
#  ('Chrysler Prowler', 0.9232240915298462)]

# %%
model

# %%
import numpy as np
def cosine_distance (model, word,target_list , num) :
    cosine_dict ={}
    word_list = []
    a = model.wv[word]
    for item in target_list :
        if item != word :
            b = model.wv[item]
            cos_sim = np.dot(a, b)/(np.linalg.norm(a)*np.linalg.norm(b))
            cosine_dict[item] = cos_sim
    dist_sort=sorted(cosine_dict.items(), key=lambda dist: dist[1],reverse = True) ## in Descending order
    for item in dist_sort:
        word_list.append((item[0], item[1]))
    return word_list[0:num]

# %%
# only get the unique Maker_Model
Maker_Model = list(df.Maker_Model.unique())

# Show the most similar Mercedes-Benz SLK-Class by cosine distance
cosine_distance(model,'Mercedes-Benz SLK-Class',Maker_Model,5)
# Out:
# [('Mercedes-Benz SL-Class', 0.9813322),
#  ('Cadillac XLR-V', 0.96829957),
#  ('Mercedes-Benz SLC-Class', 0.9639554),
#  ('Porsche Boxster', 0.9320353),
#  ('Chrysler Prowler', 0.92322415)]

# %% [markdown]
# # Activity

# %% [markdown]
# 1. Use the customer complaint data to estimate the word embedding vectors
# 2. Find similar words to 'debt', 'collection', 'risk'
